# %% [markdown]
# <a href="https://colab.research.google.com/github/francomanca93/fundamentos-practicos-de-machine-learning/blob/main/1.fundamentos-practicos/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
series = pd.Series( [5, 10, 15, 20, 25] )
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series( ['p', 'l', 'a', 't', 'z', 'i'] )
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %%
lst = ['Hola', 'mundo', 'robótico']
df = pd.DataFrame(lst)
print(df)
# Out:
#           0
# 0      Hola
# 1     mundo
# 2  robótico

# %%
data = { 'Nombre': ['Juan', 'Ana', 'Jose', 'Arturo' ], 
        'Edad' : [25, 18, 23, 27], 
        'Pais': ['MX', 'CO', 'BR', 'MX'] }
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad Pais
# 0    Juan    25   MX
# 1     Ana    18   CO
# 2    Jose    23   BR
# 3  Arturo    27   MX

# %%
print(df[[ 'Nombre', 'Pais' ]])
# Out:
#    Nombre Pais
# 0    Juan   MX
# 1     Ana   CO
# 2    Jose   BR
# 3  Arturo   MX

# %%
data = pd.read_csv('canciones-2018.csv')
data.head(5)
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
artista = data.artists
artista[5]
# Out:
# 'Post Malone'

# %%
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
data.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
data.shape
# Out:
# (100, 16)

# %%
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
data.sort_index(axis = 0, ascending = False)
# Out:
#                        id  ... time_signature
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 94  3GVkPk8mqxz0itaAriG1L  ...            4.0
# 93  2xGjteMU3E1tkEPVFBO08  ...            4.0
# 92  2P91MQbaiQOfbiz9VqhqK  ...            4.0
# 91  6vN77lE9LK6HP2DewaN6H  ...            4.0
# 90  5N5k9nd479b1xpDZ4usjr  ...            4.0
# 89  3xcCix7Jv1Rp90YVmgo35  ...            4.0
# 88  3Ga6eKrUFf12ouh9Yw3v2  ...            4.0
# 87  5Y9fnynLlIvqtM710MHzf  ...            4.0
# 86  5Z3GHaZ6ec9bsiI5Benrb  ...            4.0
# 85  5cepAtqnEQ6yVG6088zMM  ...            4.0
# 84  1bhUWB0zJMIKr9yVPrkEu  ...            3.0
# 83  48zFZh27QU5qsrBjn4C2F  ...            4.0
# 82  7KXjTSCq5nL1LoYtL7XAw  ...            4.0
# 81  2UVbBKQOdFAekPTRsnkzc  ...            4.0
# ...
